# %% [markdown]
# # 基本概念
# 算子是计算图中的基本操作单元，包括加减乘除、卷积、激活函数等
#
# 作用：
# * 前向计算：执行具体的运算
# * 反向梯度计算：定义如何传播梯度
#
# ## 分类
# 按照功能可以分为张量操作算子、神经网络算子、数据流算子、控制流算子
#
# ## 算子间依赖关系
# 在计算图中要避免循环依赖。
# * 直接依赖
# * 间接依赖
# * 相互独立
